# %%
import seaborn as sns

sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
surname_df = sns.load_dataset('tips')

surname_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.displot(surname_df['sex'])

# %%
sns.displot(surname_df['smoker'])

# %%
sns.displot(surname_df['day'])

# %%
sns.displot(surname_df['time'])

# %%
sns.boxplot(surname_df['total_bill'])
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.boxplot(surname_df['tip'])
# Out:
# <Axes: ylabel='tip'>

# %%
sns.boxplot(surname_df['size'])
# Out:
# <Axes: ylabel='size'>

# %%
sns.boxplot(surname_df)
# Out:
# <Axes: >

# %%
sns.histplot(surname_df['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(surname_df['tip'])
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.histplot(surname_df['size'])
# Out:
# <Axes: xlabel='size', ylabel='Count'>

# %%
sns.histplot(surname_df)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.violinplot(surname_df['total_bill'])
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.violinplot(surname_df['tip'])
# Out:
# <Axes: ylabel='tip'>

# %%
sns.violinplot(surname_df['size'])
# Out:
# <Axes: ylabel='size'>

# %%
sns.violinplot(surname_df)
# Out:
# <Axes: >

# %%
surname_df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.displot(data = surname_df, y = 'total_bill')

# %%
sns.displot(data = surname_df, y = 'tip')

# %%
sns.displot(data = surname_df, x = 'sex')

# %%
sns.displot(data = surname_df, y = 'smoker')

# %%
sns.displot(data = surname_df, y = 'day')

# %%
sns.displot(data = surname_df, y = 'time')

# %%
sns.displot(data = surname_df, x = 'size')

# %%
sns.boxplot(data = surname_df, y = 'total_bill')
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.boxplot(data = surname_df, y = 'tip')
# Out:
# <Axes: ylabel='tip'>

# %%
sns.boxplot(data = surname_df, y = 'size')
# Out:
# <Axes: ylabel='size'>

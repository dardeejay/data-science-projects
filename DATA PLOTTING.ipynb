# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv('student_info_dup.csv')

# %%
df.rename(columns={'weight(kg)':'weight'}, inplace=True)

# %%
df.fillna(0, inplace = True)

# %%
df
# Out:
#     student_id  first_name    last_name       Gender  YEAR program  \
# 0     20231001       Lemmy       Mazzey  Genderqueer    21   BSEMC
# 1     20231002        Gabi    Harrisson       Female    25    BSCS
# 2     20231003      Ursula       Marcus       Female    16   BSEMC
# 3     20231004       Lydia       Habble       Female    17    BSIT
# 4     20231005       Nolly       Mackro         Male    18    BSCS
# 5     20231006      Easter       Beazey       Female    20   BSEMC
# 6     20231007   Guglielmo        Mordy         Male    16   BSEMC
# 7     20231008     Melinde    Jochanany       Female    20    BSCS
# 8     20231009     Natalie        Agate       Female    22    BSCS
# 9     20231010       Vinny    Battaille       Female    24   BSEMC
# 10    20231011     Terrijo        Keele       Female    20    BSIT
# 11    20231012      Maisey     McCotter       Female    19    BSIT
# 12    20231013    Oliviero      Cromack         Male    16    BSCS
# ...

# %%
df
# Out:
#     student_id  first_name    last_name       Gender  YEAR program  \
# 0     20231001       Lemmy       Mazzey  Genderqueer    21   BSEMC
# 1     20231002        Gabi    Harrisson       Female    25    BSCS
# 2     20231003      Ursula       Marcus       Female    16   BSEMC
# 3     20231004       Lydia       Habble       Female    17    BSIT
# 4     20231005       Nolly       Mackro         Male    18    BSCS
# 5     20231006      Easter       Beazey       Female    20   BSEMC
# 6     20231007   Guglielmo        Mordy         Male    16   BSEMC
# 7     20231008     Melinde    Jochanany       Female    20    BSCS
# 8     20231009     Natalie        Agate       Female    22    BSCS
# 9     20231010       Vinny    Battaille       Female    24   BSEMC
# 10    20231011     Terrijo        Keele       Female    20    BSIT
# 11    20231012      Maisey     McCotter       Female    19    BSIT
# 12    20231013    Oliviero      Cromack         Male    16    BSCS
# ...

# %%
row_count = np.arange(df.shape[0])
plt.plot(row_count, df['weight'])

# %%
plt.stem(row_count, df['Math'])
# Out:
# <StemContainer object of 3 artists>

# %%
plt.stem(row_count, df['Math'])
# Out:
# <StemContainer object of 3 artists>

# %%
plt.hist(df['weight'])
# Out:
# (array([14.,  0.,  0.,  2.,  9.,  6., 12.,  5.,  6.,  1.]),
#  array([  0. ,  11.2,  22.4,  33.6,  44.8,  56. ,  67.2,  78.4,  89.6,
#         100.8, 112. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['height(cm)'])
# Out:
# (array([17.,  0.,  0.,  0.,  0.,  0.,  1.,  9., 12., 16.]),
#  array([  0. ,  18.5,  37. ,  55.5,  74. ,  92.5, 111. , 129.5, 148. ,
#         166.5, 185. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['Math'])
# Out:
# (array([ 4.,  3.,  7.,  7.,  6.,  4.,  4.,  2.,  8., 10.]),
#  array([ 70.,  73.,  76.,  79.,  82.,  85.,  88.,  91.,  94.,  97., 100.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['Science'])
# Out:
# (array([7., 4., 5., 5., 4., 8., 2., 8., 6., 6.]),
#  array([ 70.,  73.,  76.,  79.,  82.,  85.,  88.,  91.,  94.,  97., 100.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['History'])
# Out:
# (array([9., 5., 4., 6., 8., 3., 2., 7., 8., 3.]),
#  array([ 71. ,  73.9,  76.8,  79.7,  82.6,  85.5,  88.4,  91.3,  94.2,
#          97.1, 100. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['Art'])
# Out:
# (array([7., 5., 9., 6., 5., 5., 7., 4., 0., 7.]),
#  array([ 70.,  73.,  76.,  79.,  82.,  85.,  88.,  91.,  94.,  97., 100.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['Geography'])
# Out:
# (array([5., 5., 7., 5., 4., 4., 7., 5., 7., 6.]),
#  array([ 70.,  73.,  76.,  79.,  82.,  85.,  88.,  91.,  94.,  97., 100.]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(df['weight'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x25eacd19f88>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x25eacd1cdc8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x25eacd19708>],
#  'medians': [<matplotlib.lines.Line2D at 0x25eacd24648>],
#  'fliers': [<matplotlib.lines.Line2D at 0x25eacd24c88>],
#  'means': []}

# %%
plt.boxplot(df['height(cm)'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x25eace13148>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x25eace13f08>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x25eacdfccc8>],
#  'medians': [<matplotlib.lines.Line2D at 0x25eace19788>],
#  'fliers': [<matplotlib.lines.Line2D at 0x25eace19dc8>],
#  'means': []}

# %%
plt.boxplot(df['Geography'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x25eae2813c8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x25eae281d48>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x25eae265f08>],
#  'medians': [<matplotlib.lines.Line2D at 0x25eae285a48>],
#  'fliers': [<matplotlib.lines.Line2D at 0x25eae28e488>],
#  'means': []}

# %%
gen_dis = df.groupby('Gender').count()
gen_dis_mean = gen_dis.mean(axis=1)

plt.bar(gen_dis.index, gen_dis_mean)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.pie(gen_dis_mean, labels=gen_dis.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x25eae3c5248>,
# ...
#  [Text(1.0928299093369929, 0.1253905469263946, 'Bigender'),
#   Text(-0.4569565036563382, 1.0005951997517155, 'Female'),
#   Text(-0.8515557827414514, -0.6963136856902887, 'Genderqueer'),
#   Text(0.2796401433904897, -1.063861546539091, 'Male'),
#   Text(1.0928299049345256, -0.1253905852956902, 'Non-binary')])

# %%
plt.scatter(df['weight'], df['height(cm)'])

# %%
selected_columns = ['weight', 'height(cm)']

correlation = df[selected_columns].corr()
correlation
# Out:
#               weight  height(cm)
# weight      1.000000    0.313845
# height(cm)  0.313845    1.000000

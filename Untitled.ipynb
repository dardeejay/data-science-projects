# %%
import matplotlib.pyplot as plt

genders = ['Male', 'Female', 'Non-binary', 'Prefer not to say']
counts = [45, 55, 5, 15]


plt.pie(counts, labels=genders)
# Out:
# ([<matplotlib.patches.Wedge at 0x217d0ce3510>,
#   <matplotlib.patches.Wedge at 0x217d0ca5910>,
#   <matplotlib.patches.Wedge at 0x217d0cec610>,
#   <matplotlib.patches.Wedge at 0x217d0ced590>],
#  [Text(0.42095177560159885, 1.0162674857624154, 'Male'),
#   Text(-0.8726886534216935, -0.6696375991452626, 'Female'),
#   Text(0.6696376297853904, -0.8726886299106942, 'Non-binary'),
#   Text(1.0162675153216751, -0.4209517042392265, 'Prefer not to say')])

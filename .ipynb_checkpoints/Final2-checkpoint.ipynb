# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('bank-100.csv')

# %%
df
# Out:
#     age          job   marital          education  default  housing     loan  \
# 0    34     services  divorced           basic.9y       no      yes       no
# 1    30   technician   married  university.degree  unknown       no       no
# 2    44       admin.   married  university.degree       no      yes       no
# 3    40  blue-collar   married           basic.9y  unknown       no       no
# 4    55       admin.  divorced        high.school       no  unknown  unknown
# ..  ...          ...       ...                ...      ...      ...      ...
# 95   58  blue-collar   married            unknown  unknown      yes       no
# 96   46  blue-collar   married           basic.6y  unknown      yes      yes
# 97   33       admin.  divorced  university.degree       no       no      yes
# 98   30       admin.    single  university.degree       no      yes       no
# 99   38       admin.    single  university.degree       no      yes       no
#
#       contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0    cellular   may         mon  ...         1    999         0  nonexistent
# 1   telephone   may         tue  ...         1    999         0  nonexistent
# 2    cellular   oct         mon  ...         1    999         0  nonexistent
# 3   telephone   may         wed  ...         1    999         0  nonexistent
# 4    cellular   apr         fri  ...         2    999         0  nonexistent
# ..        ...   ...         ...  ...       ...    ...       ...          ...
# 95   cellular   aug         fri  ...         1    999         0  nonexistent
# 96  telephone   may         mon  ...         1    999         0  nonexistent
# 97   cellular   aug         mon  ...         2    999         0  nonexistent
# 98   cellular   aug         wed  ...         1    999         0  nonexistent
# 99   cellular   jun         mon  ...         3    999         0  nonexistent
#
#    emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed    y
# 0          -1.8          92.893          -46.2      1.299       5099.1   no
# 1           1.1          93.994          -36.4      4.856       5191.0   no
# 2          -1.1          94.601          -49.5      1.000       4963.6  yes
# 3           1.1          93.994          -36.4      4.858       5191.0   no
# 4          -1.8          93.075          -47.1      1.405       5099.1   no
# ..          ...             ...            ...        ...          ...  ...
# 95          1.4          93.444          -36.1      4.964       5228.1   no
# 96          1.1          93.994          -36.4      4.857       5191.0   no
# 97          1.4          93.444          -36.1      4.970       5228.1   no
# 98          1.4          93.444          -36.1      4.964       5228.1   no
# 99         -2.9          92.963          -40.8      1.260       5076.2   no
#
# [100 rows x 21 columns]

# %%
df.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
numeric_columns = df.select_dtypes(include="number").columns

# %%
df_orig = df
df_orig
# Out:
#     age          job   marital          education  default  housing     loan  \
# 0    34     services  divorced           basic.9y       no      yes       no
# 1    30   technician   married  university.degree  unknown       no       no
# 2    44       admin.   married  university.degree       no      yes       no
# 3    40  blue-collar   married           basic.9y  unknown       no       no
# 4    55       admin.  divorced        high.school       no  unknown  unknown
# ..  ...          ...       ...                ...      ...      ...      ...
# 95   58  blue-collar   married            unknown  unknown      yes       no
# 96   46  blue-collar   married           basic.6y  unknown      yes      yes
# 97   33       admin.  divorced  university.degree       no       no      yes
# 98   30       admin.    single  university.degree       no      yes       no
# 99   38       admin.    single  university.degree       no      yes       no
#
#       contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0    cellular   may         mon  ...         1    999         0  nonexistent
# 1   telephone   may         tue  ...         1    999         0  nonexistent
# 2    cellular   oct         mon  ...         1    999         0  nonexistent
# 3   telephone   may         wed  ...         1    999         0  nonexistent
# 4    cellular   apr         fri  ...         2    999         0  nonexistent
# ..        ...   ...         ...  ...       ...    ...       ...          ...
# 95   cellular   aug         fri  ...         1    999         0  nonexistent
# 96  telephone   may         mon  ...         1    999         0  nonexistent
# 97   cellular   aug         mon  ...         2    999         0  nonexistent
# 98   cellular   aug         wed  ...         1    999         0  nonexistent
# 99   cellular   jun         mon  ...         3    999         0  nonexistent
#
#    emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed    y
# 0          -1.8          92.893          -46.2      1.299       5099.1   no
# 1           1.1          93.994          -36.4      4.856       5191.0   no
# 2          -1.1          94.601          -49.5      1.000       4963.6  yes
# 3           1.1          93.994          -36.4      4.858       5191.0   no
# 4          -1.8          93.075          -47.1      1.405       5099.1   no
# ..          ...             ...            ...        ...          ...  ...
# 95          1.4          93.444          -36.1      4.964       5228.1   no
# 96          1.1          93.994          -36.4      4.857       5191.0   no
# 97          1.4          93.444          -36.1      4.970       5228.1   no
# 98          1.4          93.444          -36.1      4.964       5228.1   no
# 99         -2.9          92.963          -40.8      1.260       5076.2   no
#
# [100 rows x 21 columns]

# %%
df1= df.drop(columns = numeric_columns)
df1
# Out:
#             job   marital          education  default  housing     loan  \
# 0      services  divorced           basic.9y       no      yes       no
# 1    technician   married  university.degree  unknown       no       no
# 2        admin.   married  university.degree       no      yes       no
# 3   blue-collar   married           basic.9y  unknown       no       no
# 4        admin.  divorced        high.school       no  unknown  unknown
# ..          ...       ...                ...      ...      ...      ...
# 95  blue-collar   married            unknown  unknown      yes       no
# 96  blue-collar   married           basic.6y  unknown      yes      yes
# 97       admin.  divorced  university.degree       no       no      yes
# 98       admin.    single  university.degree       no      yes       no
# 99       admin.    single  university.degree       no      yes       no
#
#       contact month day_of_week     poutcome    y
# 0    cellular   may         mon  nonexistent   no
# 1   telephone   may         tue  nonexistent   no
# 2    cellular   oct         mon  nonexistent  yes
# 3   telephone   may         wed  nonexistent   no
# 4    cellular   apr         fri  nonexistent   no
# ..        ...   ...         ...          ...  ...
# 95   cellular   aug         fri  nonexistent   no
# 96  telephone   may         mon  nonexistent   no
# 97   cellular   aug         mon  nonexistent   no
# 98   cellular   aug         wed  nonexistent   no
# 99   cellular   jun         mon  nonexistent   no
#
# [100 rows x 11 columns]

# %%
df1['marital'].value_counts()
# Out:
# marital
# married     50
# single      35
# divorced    15
# Name: count, dtype: int64

# %%
le = LabelEncoder()

# %%
num_values = le.fit_transform(df1['marital'])

# %%
num_values
# Out:
# array([0, 1, 1, 1, 0, 2, 2, 1, 2, 1, 1, 1, 1, 2, 1, 2, 1, 2, 2, 1, 1, 2,
#        2, 1, 1, 1, 2, 0, 0, 1, 2, 1, 2, 2, 1, 0, 1, 1, 1, 1, 1, 1, 0, 0,
#        1, 2, 2, 1, 1, 1, 1, 1, 2, 0, 0, 2, 0, 2, 1, 0, 2, 1, 2, 0, 1, 1,
#        1, 1, 2, 1, 2, 2, 1, 2, 2, 1, 2, 1, 1, 1, 2, 0, 2, 1, 2, 1, 1, 2,
#        1, 2, 2, 1, 0, 1, 2, 1, 1, 0, 2, 2])

# %%
df1['marital'] = num_values
df1
# Out:
#             job  marital          education  default  housing     loan  \
# 0      services        0           basic.9y       no      yes       no
# 1    technician        1  university.degree  unknown       no       no
# 2        admin.        1  university.degree       no      yes       no
# 3   blue-collar        1           basic.9y  unknown       no       no
# 4        admin.        0        high.school       no  unknown  unknown
# ..          ...      ...                ...      ...      ...      ...
# 95  blue-collar        1            unknown  unknown      yes       no
# 96  blue-collar        1           basic.6y  unknown      yes      yes
# 97       admin.        0  university.degree       no       no      yes
# 98       admin.        2  university.degree       no      yes       no
# 99       admin.        2  university.degree       no      yes       no
#
#       contact month day_of_week     poutcome    y
# 0    cellular   may         mon  nonexistent   no
# 1   telephone   may         tue  nonexistent   no
# 2    cellular   oct         mon  nonexistent  yes
# 3   telephone   may         wed  nonexistent   no
# 4    cellular   apr         fri  nonexistent   no
# ..        ...   ...         ...          ...  ...
# 95   cellular   aug         fri  nonexistent   no
# 96  telephone   may         mon  nonexistent   no
# 97   cellular   aug         mon  nonexistent   no
# 98   cellular   aug         wed  nonexistent   no
# 99   cellular   jun         mon  nonexistent   no
#
# [100 rows x 11 columns]

# %%
df1['job'] = le.fit_transform(df1['job'])
df1
# Out:
#     job  marital          education  default  housing     loan    contact  \
# 0     7        0           basic.9y       no      yes       no   cellular
# 1     9        1  university.degree  unknown       no       no  telephone
# 2     0        1  university.degree       no      yes       no   cellular
# 3     1        1           basic.9y  unknown       no       no  telephone
# 4     0        0        high.school       no  unknown  unknown   cellular
# ..  ...      ...                ...      ...      ...      ...        ...
# 95    1        1            unknown  unknown      yes       no   cellular
# 96    1        1           basic.6y  unknown      yes      yes  telephone
# 97    0        0  university.degree       no       no      yes   cellular
# 98    0        2  university.degree       no      yes       no   cellular
# 99    0        2  university.degree       no      yes       no   cellular
#
#    month day_of_week     poutcome    y
# 0    may         mon  nonexistent   no
# 1    may         tue  nonexistent   no
# 2    oct         mon  nonexistent  yes
# 3    may         wed  nonexistent   no
# 4    apr         fri  nonexistent   no
# ..   ...         ...          ...  ...
# 95   aug         fri  nonexistent   no
# 96   may         mon  nonexistent   no
# 97   aug         mon  nonexistent   no
# 98   aug         wed  nonexistent   no
# 99   jun         mon  nonexistent   no
#
# [100 rows x 11 columns]

# %%
df1['education'] = le.fit_transform(df1['education'])
df1
# Out:
#     job  marital  education  default  housing     loan    contact month  \
# 0     7        0          2       no      yes       no   cellular   may
# 1     9        1          5  unknown       no       no  telephone   may
# 2     0        1          5       no      yes       no   cellular   oct
# 3     1        1          2  unknown       no       no  telephone   may
# 4     0        0          3       no  unknown  unknown   cellular   apr
# ..  ...      ...        ...      ...      ...      ...        ...   ...
# 95    1        1          6  unknown      yes       no   cellular   aug
# 96    1        1          1  unknown      yes      yes  telephone   may
# 97    0        0          5       no       no      yes   cellular   aug
# 98    0        2          5       no      yes       no   cellular   aug
# 99    0        2          5       no      yes       no   cellular   jun
#
#    day_of_week     poutcome    y
# 0          mon  nonexistent   no
# 1          tue  nonexistent   no
# 2          mon  nonexistent  yes
# 3          wed  nonexistent   no
# 4          fri  nonexistent   no
# ..         ...          ...  ...
# 95         fri  nonexistent   no
# 96         mon  nonexistent   no
# 97         mon  nonexistent   no
# 98         wed  nonexistent   no
# 99         mon  nonexistent   no
#
# [100 rows x 11 columns]

# %%
df1['default'] = le.fit_transform(df1['default'])
df1
# Out:
#     job  marital  education  default  housing     loan    contact month  \
# 0     7        0          2        0      yes       no   cellular   may
# 1     9        1          5        1       no       no  telephone   may
# 2     0        1          5        0      yes       no   cellular   oct
# 3     1        1          2        1       no       no  telephone   may
# 4     0        0          3        0  unknown  unknown   cellular   apr
# ..  ...      ...        ...      ...      ...      ...        ...   ...
# 95    1        1          6        1      yes       no   cellular   aug
# 96    1        1          1        1      yes      yes  telephone   may
# 97    0        0          5        0       no      yes   cellular   aug
# 98    0        2          5        0      yes       no   cellular   aug
# 99    0        2          5        0      yes       no   cellular   jun
#
#    day_of_week     poutcome    y
# 0          mon  nonexistent   no
# 1          tue  nonexistent   no
# 2          mon  nonexistent  yes
# 3          wed  nonexistent   no
# 4          fri  nonexistent   no
# ..         ...          ...  ...
# 95         fri  nonexistent   no
# 96         mon  nonexistent   no
# 97         mon  nonexistent   no
# 98         wed  nonexistent   no
# 99         mon  nonexistent   no
#
# [100 rows x 11 columns]

# %%
df1['housing'] = le.fit_transform(df1['housing'])
df1
# Out:
#     job  marital  education  default  housing     loan    contact month  \
# 0     7        0          2        0        2       no   cellular   may
# 1     9        1          5        1        0       no  telephone   may
# 2     0        1          5        0        2       no   cellular   oct
# 3     1        1          2        1        0       no  telephone   may
# 4     0        0          3        0        1  unknown   cellular   apr
# ..  ...      ...        ...      ...      ...      ...        ...   ...
# 95    1        1          6        1        2       no   cellular   aug
# 96    1        1          1        1        2      yes  telephone   may
# 97    0        0          5        0        0      yes   cellular   aug
# 98    0        2          5        0        2       no   cellular   aug
# 99    0        2          5        0        2       no   cellular   jun
#
#    day_of_week     poutcome    y
# 0          mon  nonexistent   no
# 1          tue  nonexistent   no
# 2          mon  nonexistent  yes
# 3          wed  nonexistent   no
# 4          fri  nonexistent   no
# ..         ...          ...  ...
# 95         fri  nonexistent   no
# 96         mon  nonexistent   no
# 97         mon  nonexistent   no
# 98         wed  nonexistent   no
# 99         mon  nonexistent   no
#
# [100 rows x 11 columns]

# %%
df1['loan'] = le.fit_transform(df1['loan'])
df1
# Out:
#     job  marital  education  default  housing  loan    contact month  \
# 0     7        0          2        0        2     0   cellular   may
# 1     9        1          5        1        0     0  telephone   may
# 2     0        1          5        0        2     0   cellular   oct
# 3     1        1          2        1        0     0  telephone   may
# 4     0        0          3        0        1     1   cellular   apr
# ..  ...      ...        ...      ...      ...   ...        ...   ...
# 95    1        1          6        1        2     0   cellular   aug
# 96    1        1          1        1        2     2  telephone   may
# 97    0        0          5        0        0     2   cellular   aug
# 98    0        2          5        0        2     0   cellular   aug
# 99    0        2          5        0        2     0   cellular   jun
#
#    day_of_week     poutcome    y
# 0          mon  nonexistent   no
# 1          tue  nonexistent   no
# 2          mon  nonexistent  yes
# 3          wed  nonexistent   no
# 4          fri  nonexistent   no
# ..         ...          ...  ...
# 95         fri  nonexistent   no
# 96         mon  nonexistent   no
# 97         mon  nonexistent   no
# 98         wed  nonexistent   no
# 99         mon  nonexistent   no
#
# [100 rows x 11 columns]

# %%
df1['contact'] = le.fit_transform(df1['contact'])
df1
# Out:
#     job  marital  education  default  housing  loan  contact month  \
# 0     7        0          2        0        2     0        0   may
# 1     9        1          5        1        0     0        1   may
# 2     0        1          5        0        2     0        0   oct
# 3     1        1          2        1        0     0        1   may
# 4     0        0          3        0        1     1        0   apr
# ..  ...      ...        ...      ...      ...   ...      ...   ...
# 95    1        1          6        1        2     0        0   aug
# 96    1        1          1        1        2     2        1   may
# 97    0        0          5        0        0     2        0   aug
# 98    0        2          5        0        2     0        0   aug
# 99    0        2          5        0        2     0        0   jun
#
#    day_of_week     poutcome    y
# 0          mon  nonexistent   no
# 1          tue  nonexistent   no
# 2          mon  nonexistent  yes
# 3          wed  nonexistent   no
# 4          fri  nonexistent   no
# ..         ...          ...  ...
# 95         fri  nonexistent   no
# 96         mon  nonexistent   no
# 97         mon  nonexistent   no
# 98         wed  nonexistent   no
# 99         mon  nonexistent   no
#
# [100 rows x 11 columns]

# %%
df1['month'] = le.fit_transform(df1['month'])
df1
# Out:
#     job  marital  education  default  housing  loan  contact  month  \
# 0     7        0          2        0        2     0        0      5
# 1     9        1          5        1        0     0        1      5
# 2     0        1          5        0        2     0        0      7
# 3     1        1          2        1        0     0        1      5
# 4     0        0          3        0        1     1        0      0
# ..  ...      ...        ...      ...      ...   ...      ...    ...
# 95    1        1          6        1        2     0        0      1
# 96    1        1          1        1        2     2        1      5
# 97    0        0          5        0        0     2        0      1
# 98    0        2          5        0        2     0        0      1
# 99    0        2          5        0        2     0        0      3
#
#    day_of_week     poutcome    y
# 0          mon  nonexistent   no
# 1          tue  nonexistent   no
# 2          mon  nonexistent  yes
# 3          wed  nonexistent   no
# 4          fri  nonexistent   no
# ..         ...          ...  ...
# 95         fri  nonexistent   no
# 96         mon  nonexistent   no
# 97         mon  nonexistent   no
# 98         wed  nonexistent   no
# 99         mon  nonexistent   no
#
# [100 rows x 11 columns]

# %%
df1['day_of_week'] = le.fit_transform(df1['day_of_week'])
df1
# Out:
#     job  marital  education  default  housing  loan  contact  month  \
# 0     7        0          2        0        2     0        0      5
# 1     9        1          5        1        0     0        1      5
# 2     0        1          5        0        2     0        0      7
# 3     1        1          2        1        0     0        1      5
# 4     0        0          3        0        1     1        0      0
# ..  ...      ...        ...      ...      ...   ...      ...    ...
# 95    1        1          6        1        2     0        0      1
# 96    1        1          1        1        2     2        1      5
# 97    0        0          5        0        0     2        0      1
# 98    0        2          5        0        2     0        0      1
# 99    0        2          5        0        2     0        0      3
#
#     day_of_week     poutcome    y
# 0             1  nonexistent   no
# 1             3  nonexistent   no
# 2             1  nonexistent  yes
# 3             4  nonexistent   no
# 4             0  nonexistent   no
# ..          ...          ...  ...
# 95            0  nonexistent   no
# 96            1  nonexistent   no
# 97            1  nonexistent   no
# 98            4  nonexistent   no
# 99            1  nonexistent   no
#
# [100 rows x 11 columns]

# %%
df1['y'] = le.fit_transform(df1['y'])
df1

# %%
import pandas as pd

# %%
df = pd.read_csv('student_info.csv')

# %%
df.filter(items=['program', 'math','science','history','art','geography']).groupby(['program']).mean()
# Out:
#               math    science    history        art  geography
# program
# BSCS     84.687500  83.687500  84.125000  82.312500  85.750000
# BSEMC    88.187500  86.500000  85.875000  81.250000  86.125000
# BSIT     85.611111  83.722222  84.555556  84.833333  83.055556

# %%
df
# Out:
#     student_id  first_name    last_name       gender  age program  \
# 0     20231001       Lemmy       Mazzey  Genderqueer   21   BSEMC
# 1     20231002        Gabi    Harrisson       Female   25    BSCS
# 2     20231003      Ursula       Marcus       Female   16   BSEMC
# 3     20231004       Lydia       Habble       Female   17    BSIT
# 4     20231005       Nolly       Mackro         Male   18    BSCS
# 5     20231006      Easter       Beazey       Female   20   BSEMC
# 6     20231007   Guglielmo        Mordy         Male   16   BSEMC
# 7     20231008     Melinde    Jochanany       Female   20    BSCS
# 8     20231009     Natalie        Agate       Female   22    BSCS
# 9     20231010       Vinny    Battaille       Female   24   BSEMC
# 10    20231011     Terrijo        Keele       Female   20    BSIT
# 11    20231012      Maisey     McCotter       Female   19    BSIT
# 12    20231013    Oliviero      Cromack         Male   16    BSCS
# ...
